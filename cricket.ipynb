# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
cricket_data = pd.read_csv('cricket.csv')
cricket_data.head()
# Out:
#    match_id          team     opponent  team_score_innings1  toss  \
# 0         1      Pakistan      England                  153  bowl
# 1         2         India    Sri Lanka                  160   bat
# 2         3   West Indies        India                  182  bowl
# 3         4  South Africa  New Zealand                  119   bat
# 4         5     Sri Lanka        India                  196   bat
#
#                                     ground  result
# 0                          Gaddafi Stadium       1
# 1              Dubai International Stadium       0
# 2                             Old Trafford       0
# 3                                   Lord's       0
# 4  Pallekele International Cricket Stadium       1

# %%
x = cricket_data.drop(columns=['match_id','result'])
y = cricket_data['result']

# %%
x.head()
# Out:
#            team     opponent  team_score_innings1  toss  \
# 0      Pakistan      England                  153  bowl
# 1         India    Sri Lanka                  160   bat
# 2   West Indies        India                  182  bowl
# 3  South Africa  New Zealand                  119   bat
# 4     Sri Lanka        India                  196   bat
#
#                                     ground
# 0                          Gaddafi Stadium
# 1              Dubai International Stadium
# 2                             Old Trafford
# 3                                   Lord's
# 4  Pallekele International Cricket Stadium

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1
# Name: result, dtype: int64

# %%
categorical_cols = ['team', 'opponent', 'toss', 'ground']
numerical_cols = ['team_score_innings1']

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols),
        ('num', 'passthrough', numerical_cols)
    ]
)

# %%
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', LogisticRegression(max_iter=1000))
])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['team', 'opponent', 'toss',
#                                                    'ground']),
#                                                  ('num', 'passthrough',
#                                                   ['team_score_innings1'])])),
#                 ('classifier', LogisticRegression(max_iter=1000))])

# %%
y_pred = model.predict(x_test)

# %%
print(y_pred)
# Out:
# [1 1 0 ... 0 0 1]

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.519
# Confusion Matrix:
#  [[606 424]
#  [538 432]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.53      0.59      0.56      1030
#            1       0.50      0.45      0.47       970
#
#     accuracy                           0.52      2000
#    macro avg       0.52      0.52      0.52      2000
# weighted avg       0.52      0.52      0.52      2000

# %%
# Define the sample match as a DataFrame
sample_input = pd.DataFrame([{
    'team': 'Sri Lanka',
    'opponent': 'England',
    'team_score_innings1': 143,
    'toss': 'bat',
    'ground': 'Gaddafi Stadium'
}])

# Make prediction
y_pred = model.predict(sample_input)

# Output result
print("Predicted Result:", "Win" if y_pred[0] == 1 else "Loss")
# Out:
# Predicted Result: Loss

# %%
import joblib
joblib.dump(model, 'cricket_win_predictor.pkl')
# Out:
# ['cricket_win_predictor.pkl']
